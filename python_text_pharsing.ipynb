# %%
f= open(file='C:/Users/User/Desktop/RevitToPCF_Error.log',mode='rt',encoding='utf-8')

# %%
while True:
    line = f.readline()
    if not line: break
    print(line)
f.close()
# Out:
# [2021-02-15 11:42:03:401] - Level: 안내, E_ID: -1, Line No: Export ISO ======================, Desc: Start
#
# [2021-02-15 11:42:25:160] - Level: 경고, E_ID: 16294342, Line No: AF-1012B_07, Desc: Element ID - 16294349 와 0.07mm 미만 DisConnect - 자동연결.
#
# [2021-02-15 11:42:25:211] - Level: 경고, E_ID: 16294349, Line No: AF-1012B_07, Desc: Element ID - 16294342 와 0.07mm 미만 DisConnect - 자동연결.
#
# [2021-02-15 11:42:37:656] - Level: 경고, E_ID: 16510927, Line No: AP-0324_01, Desc: Element ID - 25611147 와 0.07mm 미만 DisConnect - 자동연결.
#
# [2021-02-15 11:42:39:405] - Level: 경고, E_ID: 25611147, Line No: AP-0324_01, Desc: Element ID - 16510927 와 0.07mm 미만 DisConnect - 자동연결.
#
# [2021-02-15 11:43:19:973] - Level: 에러, E_ID: 16512603, Line No: CAOH2-0322_01, Desc: 라인이 두개 이상으로 나누어져 있어 ISO 생성이 불가합니다.
#
# [2021-02-15 11:44:48:613] - Level: 경고, E_ID: 16495342, Line No: FR-0619_01, Desc: Element ID - 24164759 와 0.07mm 미만 DisConnect - 자동연결.
#
# ...
